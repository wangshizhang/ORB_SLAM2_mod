# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
files = os.listdir()

# %%
orb_data = pd.read_csv("test_orb1.csv")

# %%
for i in range(orb_data.shape[1]):
    plt.plot(orb_data.iloc[:,i],label = name_lists[i])
plt.legend()

# %%
for i in range(orb_data.shape[1]):
    new_sum = orb_data.iloc[:,0].copy()
    for j in range(i):
        new_sum += orb_data.iloc[:,j+1]
    plt.plot(new_sum,label = name_lists[i])
plt.legend()
